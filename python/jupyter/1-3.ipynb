# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

#한글폰트지정
mpl.rc('font', family='nanumgothic')
mpl.rc('axes', unicode_minus=False)

# %%
df_exam = pd.read_csv('./data/exam.csv')
df_exam.plot()

# %%
# 수학 컬럼 plot
x = df_exam.id
y = df_exam.math

plt.title('수학점수')
plt.bar(x, y)
# Out:
# <BarContainer object of 20 artists>

# %%
# 영어 컬럼 plot
df_exam['english'].plot(kind='bar')

# %%
# 평균을 구해서 히스토그램으로 출력

df_exam['total'] = df_exam.math + df_exam.english + df_exam.science
df_exam['mean'] = (df_exam.math + df_exam.english + df_exam.science) / 3

t = df_exam['total']
m = df_exam['mean']

plt.title('평균분포도')
plt.hist(m)
# Out:
# (array([1., 1., 1., 1., 1., 4., 3., 4., 1., 3.]),
#  array([44.33333333, 48.16666667, 52.        , 55.83333333, 59.66666667,
#         63.5       , 67.33333333, 71.16666667, 75.        , 78.83333333,
#         82.66666667]),
#  <a list of 10 Patch objects>)
